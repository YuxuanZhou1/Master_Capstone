# %%
from riotwatcher import LolWatcher, ApiError
import pandas as pd
import csv
import playerinformation

# %%
# global variables
api_key = "RGAPI-595ca1c5-ceb8-4de2-8464-7eb8635fbf85"
watcher = LolWatcher(api_key, default_match_v5=True)
my_region = 'EUN1'
# Out:
# property 'default_match_v5' has been deprecated and can be removed

# %%
# get player name from csv
data = pd.read_csv ("EUNE_matches.csv")
my_matches = data['id'].tolist()

# %%
playerinformation.get_information(my_matches, watcher, 756, 1512, "EUNE_match_information_1.csv")
# Out:
#          gameId  gameDuration     gameVersion platformId  season  winner  \
# 0    2947163922          1247  11.20.400.7328       EUN1      11       1
# 1    2956011375          1789  11.21.403.3002       EUN1      11       2
# 2    2953636673          1626  11.20.400.7328       EUN1      11       1
# 3    2961916410          3161  11.21.403.3002       EUN1      11       1
# 4    2951441916          1386  11.20.400.7328       EUN1      11       1
# ..          ...           ...             ...        ...     ...     ...
# 751  2911305259       2278677  11.16.390.1945       EUN1      11       2
# 752  2911348895       1839260  11.16.390.1945       EUN1      11       2
# 753  2965263660          1349  11.22.406.3587       EUN1      11       2
# 754  2952380786          1978  11.20.400.7328       EUN1      11       1
# 755  2961842159          2218  11.21.403.3002       EUN1      11       1
#
#      1st_baron  1st_dragon  1st_inhibitor  1st_riftHerald  ...  \
# 0            0           2              1               1  ...
# 1            1           1              2               0  ...
# 2            1           1              1               1  ...
# 3            1           2              2               1  ...
# 4            0           1              1               0  ...
# ..         ...         ...            ...             ...  ...
# 751          2           1              2               2  ...
# 752          2           2              2               2  ...
# 753          2           2              2               1  ...
# 754          0           1              1               2  ...
# 755          1           1              1               2  ...
#
#      t2_baron_kills  t2_champ_kills  t2_dragon_kills  t2_inhibitor_kills  \
# 0                 0              21                1                   0
# 1                 0              42                1                   2
# 2                 0              18                0                   0
# 3                 0              63                3                   1
# 4                 0              16                0                   0
# ..              ...             ...              ...                 ...
# 751               1              50                4                   2
# 752               1              28                1                   2
# 753               1              29                3                   2
# 754               0              22                2                   0
# 755               0              31                1                   0
#
#      t2_riftHerald_kills  t2_tower_kills  t2_team_assists  t2_team_gold_earn  \
# 0                      0               1               16              36888
# 1                      0               9               56              63609
# 2                      0               2               17              41809
# 3                      0               6               73              92336
# 4                      0               1               12              32634
# ..                   ...             ...              ...                ...
# 751                    1               9               69              74535
# 752                    1              10               51              59229
# 753                    0              10               17              47346
# 754                    1               2               21              52516
# 755                    1               1               46              60068
#
#      t2_team_gold_spen  t2_team_kda
# 0                35325     1.027778
# 1                54530     3.266667
# 2                40320     1.129032
# 3                86925     1.462366
# 4                29093     0.717949
# ..                 ...          ...
# 751              64675     2.975000
# 752              48575     2.821429
# 753              38635     4.600000
# 754              50133     1.162162
# 755              56400     1.878049
#
# [756 rows x 31 columns]
