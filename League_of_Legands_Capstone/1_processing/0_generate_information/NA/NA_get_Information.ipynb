# %%
from riotwatcher import LolWatcher, ApiError
import pandas as pd
import csv
import playerinformation

# %%
# global variables
api_key = "RGAPI-aba1c72d-67fc-41ff-8232-9e727e34f9de"
watcher = LolWatcher(api_key)
my_region = 'AMERICAS'

# %%
# get player name from csv
data = pd.read_csv ("NA_matches.csv")
my_matches = data['id'].tolist()

# %%
playerinformation.get_information(my_matches, watcher, 0, 798, "NA_match_information.csv")
# Out:
#         gameId  gameDuration     gameVersion platformId  season  winner  \
# 0   4093005308          2119  11.22.406.3587        NA1      11       2
# 1   4075410742          1931  11.20.400.7328        NA1      11       1
# 2   3905301824       1065734  11.10.374.9538        NA1      11       1
# 3   3904688211       2277873  11.10.374.9538        NA1      11       1
# 4   4092696441          2073  11.22.406.3587        NA1      11       2
# ..         ...           ...             ...        ...     ...     ...
# 95  4067556134           702  11.20.400.7328        NA1      11       1
# 96  3911072357        685893  11.10.374.9538        NA1      11       1
# 97  3911039621        194875  11.10.374.9538        NA1      11       2
# 98  4092683793          2109  11.22.406.3587        NA1      11       2
# 99  4092627635          1970  11.22.406.3587        NA1      11       1
#
#     1st_baron  1st_dragon  1st_inhibitor  1st_riftHerald  ...  t2_baron_kills  \
# ...
