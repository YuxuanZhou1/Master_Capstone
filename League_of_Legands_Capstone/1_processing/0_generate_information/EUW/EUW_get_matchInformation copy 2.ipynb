# %%
from riotwatcher import LolWatcher, ApiError
import pandas as pd
import csv
import playerinformation

# %%
# global variables
api_key = "RGAPI-595ca1c5-ceb8-4de2-8464-7eb8635fbf85"
watcher = LolWatcher(api_key, default_match_v5=True)
my_region = 'EUW1'
# Out:
# property 'default_match_v5' has been deprecated and can be removed

# %%
# get player name from csv
data = pd.read_csv ("EUW_matches.csv")
my_matches = data['id'].tolist()

# %%
playerinformation.get_information(my_matches, watcher, 3040, 4632, "EUW_match_information_2.csv")
# Out:
#           gameId  gameDuration     gameVersion platformId  season  winner  \
# 0     5539686518          2458  11.22.406.3587       EUW1      11       1
# 1     5539731659          1737  11.22.406.3587       EUW1      11       1
# 2     5540212367          2032  11.22.406.3587       EUW1      11       1
# 3     5540078457           964  11.22.406.3587       EUW1      11       1
# 4     5540685027          1630  11.22.406.3587       EUW1      11       1
# ...          ...           ...             ...        ...     ...     ...
# 1585  5537934278          1534  11.22.406.3587       EUW1      11       1
# 1586  5537053358           203  11.22.406.3587       EUW1      11       1
# 1587  5536803125          1825  11.22.406.3587       EUW1      11       1
# 1588  5501291740          1280  11.20.400.7328       EUW1      11       1
# 1589  5498984172          1507  11.20.400.7328       EUW1      11       2
#
#       1st_baron  1st_dragon  1st_inhibitor  1st_riftHerald  ...  \
# ...
